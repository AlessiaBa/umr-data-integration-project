# %%
# %pip install thefuzz
# %pip install python-levenshtein
# %pip install vega-datasets

# IMPORTANT always restart from here!
import pandas as pd 
import numpy as np
import altair as alt
from thefuzz import fuzz

# parameters

countriesOfInterest = ['United States of America', 'Germany', 'Russian Federation', 'Belarus', 'China', 'Colombia', 'Brazil', 'Algeria', 'Egypt', 'South Africa']
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: thefuzz in /home/b/.local/lib/python3.8/site-packages (0.19.0)
# WARNING: You are using pip version 21.1.1; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-levenshtein in /home/b/.local/lib/python3.8/site-packages (0.12.2)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from python-levenshtein) (45.2.0)
# WARNING: You are using pip version 21.1.1; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting vega-datasets
#   Using cached vega_datasets-0.9.0-py3-none-any.whl (210 kB)
# Requirement already satisfied: pandas in /home/b/.local/lib/python3.8/site-packages (from vega-datasets) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/lib/python3/dist-packages (from pandas->vega-datasets) (2.7.3)
# Requirement already satisfied: numpy>=1.16.5 in /home/b/.local/lib/python3.8/site-packages (from pandas->vega-datasets) (1.20.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas->vega-datasets) (2019.3)
# Installing collected packages: vega-datasets
# Successfully installed vega-datasets-0.9.0
# WARNING: You are using pip version 21.1.1; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# I. Prepare CPI dataset

cpi = pd.read_csv('../0_datasets/cpi.csv', sep=',', na_values=['-'])
cpi.head()
# Out:
#   Jurisdiction  1998  1999  2000  2001  2002  2003  2004  2005  2006  2007  \
# 0  Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   2.5   NaN   1.8
# 1      Albania   NaN   2.3   NaN   NaN   2.5   2.5   2.5   2.4   2.6   2.9
# 2      Algeria   NaN   NaN   NaN   NaN   NaN   2.6   2.7   2.8   3.1   3.0
# 3       Angola   NaN   NaN   1.7   NaN   1.7   1.8   2.0   2.0   2.2   2.2
# 4    Argentina   3.0   3.0   3.5   3.5   2.8   2.5   2.5   2.8   2.9   2.9
#
#    2008  2009  2010  2011  2012  2013  2014  2015
# 0   1.5   1.3   1.4  1.52   8.0   8.0  12.0  11.0
# 1   3.4   3.2   3.3  3.05  33.0  31.0  33.0  36.0
# 2   3.2   2.8   2.9  2.90  34.0  36.0  36.0  36.0
# 3   1.9   1.9   1.9  2.01  22.0  23.0  19.0  15.0
# 4   2.9   2.9   2.9  3.00  35.0  34.0  34.0  32.0

# %%
# A) Normalize values between (1..0), rename 'Jurisdiction' to 'Country'
# From 2012 onwards, the methology changed (scala went from 10-0 to 100-0)
years100 = ['2012', '2013', '2014', '2015']
cpi_norm = cpi.drop('Jurisdiction', axis=1)
cpi_norm[years100] = cpi_norm[years100].applymap(lambda v: v / 10.0)
cpi_norm /= 10.0
cpi_norm['Country'] = cpi['Jurisdiction']

# B) Long Format
# Long format is more desireable, as we want to join it with WVS later on
cpi_norm = cpi_norm.melt(id_vars=['Country'], var_name='Year', value_name='Value')
cpi_norm['Country'] = cpi_norm['Country'].replace({'USA': 'United States of America', 'Russia': 'Russian Federation'})

# C) Filter countries and invert values from (1..0) to (0..1) [1 is best]
#cpi_norm = cpi_norm.loc[cpi_norm['Country'].isin(countriesOfInterest)]
cpi_norm['Value'] = 1 - cpi_norm['Value']
 
# D) add constant Variables column
cpi_norm['Variable'] = 'Corruption Perception Index'

cpi_norm
# Out:
#           Country  Year  Value                     Variable
# 0     Afghanistan  1998    NaN  Corruption Perception Index
# 1         Albania  1998    NaN  Corruption Perception Index
# 2         Algeria  1998    NaN  Corruption Perception Index
# 3          Angola  1998    NaN  Corruption Perception Index
# 4       Argentina  1998   0.70  Corruption Perception Index
# ...           ...   ...    ...                          ...
# 4081     Viet Nam  2015    NaN  Corruption Perception Index
# 4082        Yemen  2015   0.82  Corruption Perception Index
# 4083   Yugoslavia  2015    NaN  Corruption Perception Index
# 4084       Zambia  2015   0.62  Corruption Perception Index
# 4085     Zimbabwe  2015   0.79  Corruption Perception Index
#
# [4086 rows x 4 columns]

# %%
# II. Prepare WVS-Variables dataset

wvs_vars = pd.read_csv('../0_datasets/wvs-variables.csv')
wvs_vars.head()
# Out:
#   Variable                            Title WVS7 WVS6 WVS5 WVS4 WVS3 WVS2 WVS1
# 0     A001        Important in life: Family   Q1   V4   V4   V4   V4   V5  NaN
# 1     A002       Important in life: Friends   Q2   V5   V5   V5   V5   V6  NaN
# 2     A003  Important in life: Leisure time   Q3   V6   V6   V6   V6   V7  NaN
# 3     A004      Important in life: Politics   Q4   V7   V7   V7   V7   V8  NaN
# 4     A005          Important in life: Work   Q5   V8   V8   V8   V8   V4  NaN

# %%
# A) Remove unwanted prefixes 
# We want to use the Title as human-readable labels later on
wvs_vars['Title'].replace(r'[^ ]+-\ ', '', regex=True, inplace=True)

# B) Drop unneeded internal variables
wvs_vars = wvs_vars.drop(wvs_vars.loc[:, 'WVS7':'WVS1'], axis=1)

# C) Set the variable name as key
wvs_vars.set_index('Variable', inplace=True)
wvs_vars.head()
# Out:
#                                     Title
# Variable
# A001            Important in life: Family
# A002           Important in life: Friends
# A003      Important in life: Leisure time
# A004          Important in life: Politics
# A005              Important in life: Work

# %%
# D) some exploration: grouping variable names by levensthein distance

# code übernommen von https://stackoverflow.com/questions/35171710/how-to-group-words-whose-levenshtein-distance-is-more-than-80-percent-in-python

combined_list = wvs_vars['Title'].tolist()

grs = list() # groups of names with distance > 80
for name in combined_list:
    for g in grs:
        if all(fuzz.partial_ratio(name, w) > 55 for w in g):
            g.append(name)
            break
    else:
        grs.append([name, ])

for group in grs:
    print('-')
    for e in group:
        print('    ', wvs_vars.loc[wvs_vars['Title'] == e].index[0], e)
# Out:
# -
#      A001 Important in life: Family
#      A002 Important in life: Friends
#      A003 Important in life: Leisure time
#      A004 Important in life: Politics
#      A005 Important in life: Work
#      A006 Important in life: Religion
#      A029 Important child qualities: independence
#      A030 Important child qualities: Hard work
#      A032 Important child qualities: feeling of responsibility
#      A034 Important child qualities: imagination
#      A035 Important child qualities: tolerance and respect for other people
#      A038 Important child qualities: thrift saving money and things
#      A039 Important child qualities: determination perseverance
#      A040 Important child qualities: religious faith
#      A041 Important child qualities: unselfishness
#      A042 Important child qualities: obedience
#      A043B Important child qualities: Self-expression
# -
#      A008 Feeling of happiness
#      E036 Private vs state ownership of business
# -
#      A009 State of health (subjective)
#      X045 Social class (subjective)
#      X045B Social class (subjective) with 6 categories
# -
#      A010 Ever felt very excited or interested
#      A011 Ever felt restless
#      A013 Ever felt very lonely or remote from other people
#      A015 Ever felt bored
# -
#      A012 Ever felt proud because someone complimented you
#      A014 Ever felt pleased about having accomplished something
# -
#      A016 Ever felt on top of the world
#      A018 Ever felt that things were going your way
# -
#      A017 Ever felt depressed or very unhappy
#      E032 Freedom or equality
# -
#      A019 Ever felt upset because somebody criticized you
#      D077 Wife must obey
# -
#      A025 Respect and love for parents
#      D030 Important for succesful marriage: Respect and appreciation
# -
#      A026 Parents responsibilities to their children
#      D026_03 Duty towards society to have children
#      X011A Have you had any children
# -
#      A027 Important child qualities: Good manners
#      C015 Important in a job: good hours
#      C023 Important in a job: good chances for promotion
# -
#      A044 What children should learn 1
#      A045 What children should learn 2
#      C060 How business and industry should be managed
# -
#      A046 Abortion when the mothers health is at risk
#      A048 Abortion when woman not married
# -
#      A047 Abortion when child physically handicapped
# -
#      A049 Abortion if not wanting more children
#      D062 Women want a home and children
#      F114C Justifiable: Parents beating children
# -
#      A057 Spend time with parents or other relatives
#      A058 Spend time with friends
#      A059 Spend time with colleagues from work
#      A060 Spend time with people at your church, mosque or synagogue
#      A061 Spend time with people at sport, culture, communal organization
#      X001 Sex
# -
#      A062 How often discusses political matters with friends
#      D059 Men make better political leaders than women do
#      E112 Rate political system as it was before
#      E113 Rate political system in ten years
# -
#      A063 Persuading friends, relatives or fellow workers
#      F053 Believe in: hell
# -
#      A064 Member: Belong to social welfare service for elderly
#      A065 Member: Belong to religious organization
#      A066 Member: Belong to education, arts, music or cultural activities
#      A067 Member: Belong to labour unions
#      A068 Member: Belong to political parties
#      A069 Member: Belong to local political actions
#      A070 Member: Belong to human rights
#      A071 Member: Belong to conservation, the environment, ecology, animal rights
#      A071B Member: Belong to conservation, the environment, ecology
#      A071C Member: Belong to animal rights
#      A072 Member: Belong to professional associations
#      A073 Member: Belong to youth work
#      A074 Member: Belong to sports or recreation
#      A075 Member: Belong to women´s group
#      A076 Member: Belong to peace movement
#      A077 Member: Belong to organization concerned with health
#      A079 Member: Belong to other groups
#      A080 Member: Belong to none
# -
#      A080_01 Member: Humanitarian or charitable organization
#      A082 Voluntary work: Unpaid work religious or church organization
#      A098 Active/Inactive membership of church or religious organization
# -
#      A080_02 Member:  Self-help group, mutual aid group
#      A106C Active/Inactive membership: Self-help group, mutual aid group
#      X051 Ethnic group
# -
#      A081 Voluntary work: Unpaid work social welfare service for elderly, handicapped or deprived people
#      A083 Voluntary work: Unpaid work education, arts, music or cultural activities
#      A084 Voluntary work: Unpaid work labour unions
#      A085 Voluntary work: Unpaid work political parties or groups
#      A086 Voluntary work: Unpaid work local political action groups
#      A087 Voluntary work: Unpaid work human rights
#      A088 Voluntary work: Unpaid work environment, conservation, animal rights
#      A088B Voluntary work: Unpaid work environment, conservation, ecology
#      A088C Voluntary work: Unpaid work animal rights
#      A089 Voluntary work: Unpaid work professional associations
#      A090 Voluntary work: Unpaid work youth work
#      A091 Voluntary work: Unpaid work sports or recreation
#      A092 Voluntary work: Unpaid work women´s group
#      A093 Voluntary work: Unpaid work peace movement
#      A094 Voluntary work: Unpaid work organization concerned with health
#      A096 Voluntary work: Unpaid work other groups
#      A097 Voluntary work: Unpaid work none
#      S024 Country - wave
#      S025 Country - year
# -
#      A099 Active/Inactive membership of sport or recreation
#      A100 Active/Inactive membership of art, music, educational
#      A101 Active/Inactive membership of labour unions
#      A102 Active/Inactive membership of political party
#      A103 Active/Inactive membership of environmental organization
#      A104 Active/Inactive membership of professional organization
#      A105 Active/Inactive membership of charitable/humanitarian organization
#      A106 Active/Inactive membership of any other organization
#      A106B Active/Inactive membership: Consumer organization
#      A106D Active/Inactive membership: Women’s group
#      S008 Interviewer number
# -
#      A107 Reasons voluntary work: Solidarity with the poor and disadvantaged
#      A108 Reasons voluntary work: Compassion for those in need
#      A109 Reasons voluntary work: Opportunity to repay something
#      A110 Reasons voluntary work: Sense of duty, moral, obligation
#      A111 Reasons voluntary work: Identifying with people who suffer
#      A112 Reasons voluntary work: Time on my hands
#      A113 Reasons voluntary work: Personal satisfaction
#      A114 Reasons voluntary work: Religious belief
#      A115 Reasons voluntary work: Help disadvantaged people
#      A116 Reasons voluntary work: Make a contribution to my local community
#      A117 Reasons voluntary work: Bring about social or political change
#      A118 Reasons voluntary work: For social reasons
#      A119 Reasons voluntary work: Gain new skills and useful experience
#      A120 Reasons voluntary work: Did not want to, but could not refuse
# -
#      A124_01 Neighbours: People with a criminal record
#      A124_02 Neighbours: People of a different race
#      A124_03 Neighbours: Heavy drinkers
#      A124_05 Neighbours: Muslims
#      A124_07 Neighbours: People who have AIDS
#      A124_09 Neighbours: Homosexuals
#      A124_10 Neighbours: Jews
#      A124_11 Neighbours: Evangelists
#      A124_12 Neighbours: People of a different religion
#      A124_13 Neighbours: People of the same religion
#      A124_15 Neighbours: Zoroastrians
#      A124_16 Neighbours: People not from country of origin
#      A124_17 Neighbours: Gypsies
#      A124_22 Neighbours: Spiritists
#      A124_23 Neighbours: Protestants
#      A124_28 Neighbours: People with large families
#      A124_29 Neighbours: Hindus
#      A124_31 Neighbours: Haitians
#      A124_36 Neighbours: Coloured people
#      A124_37 Neighbours: Indians
#      A124_43 Neighbours: People who speak a different language
#      A124_45 Neighbours: Sunnis
#      A124_46 Neighbours: Shia
#      A124_47 Neighbours: French
#      A124_48 Neighbours: British
#      A124_49 Neighbours: Iranian
#      A124_50 Neighbours: Kuwaiti
#      A124_51 Neighbours: Turkish
#      A124_52 Neighbours: Jordanian
#      A124_53 Neighbours: Kildani
#      A124_55 Neighbours: Maori
#      A124_57 Neighbours: Europeans/Pakeha
#      A124_58 Neighbours: Americans
#      A124_59 Neighbours: Chaldean
#      A124_60 Neighbours: Mapuches
#      A124_61 Neighbours: Russians
#      S017 Weight
# -
#      A124_04 Neighbours: Emotionally unstable people
#      A124_14 Neighbours: Militant minority
#      A124_18 Neighbours: Political Extremists
#      A124_19 Neighbours: Trafficants
#      A124_24 Neighbours: Christians
#      A124_34 Neighbours: Black people
#      A124_35 Neighbours: White people
# -
#      A124_06 Neighbours: Immigrants/foreign workers
#      A124_08 Neighbours: Drug addicts
#      A124_20 Neighbours: Indians or Lebanese
#      A124_27 Neighbours: Right wing extremists
#      A124_30 Neighbours: North-American persons
#      A124_38 Neighbours: Kurds, Esids
# -
#      A124_21 Neighbours: Chinese or Philippino Chinese
#      A124_32 Neighbours: Members of new religious movements
#      A124_42 Neighbours: Unmarried couples living together
#      A124_54 Neighbours: Indigenes; Aborigenes
# -
#      A124_25 Neighbours: Witchdoctors and related labels
#      A124_56 Neighbours: Pacific Islanders
# -
#      A124_33 Neighbours: Jews, Arabs, Asians, gypsies, etc
#      F034 Religious person
# -
#      A165 Most people can be trusted
#      A168 Do you think most people try to take advantage of you
#      A168A Do you think most people try to take advantage of you (10 point scale)
# -
#      A169 Good human relationships
#      D036 Important for succesful marriage: Happy sexual relationship
# -
#      A170 Satisfaction with your life
#      C006 Satisfaction with financial situation of household
#      C033 Job satisfaction
#      D002 Satisfaction with home life
#      E125 Satisfaction with the people in national office
# -
#      A173 How much freedom of choice and control
#      E129B How much more foreign aid this country should contribute
# -
#      A174 Membership consumer organisation
#      B015 Environmental action: contributed to environmental organization
# -
#      A189 Schwartz: It is important to this person to think up new ideas and be creative
#      A190 Schwartz: It is important to this person to be rich
#      A191 Schwartz: It is important to this person living in secure surroundings
#      A192 Schwartz: It is important to this person to have a good time
#      A193 Schwartz: It is important to this person to help the people nearby
#      A194 Schwartz: It is important to this person being very successful
#      A195 Schwartz: It is important to this person adventure and taking risks
#      A196 Schwartz: It is important to this person to always behave properly
#      A197 Schwartz: It is important to this person looking after the environment
#      A198 Schwartz: It is important to this person tradition
#      A199 Schwartz: It is important to this person to do something for the good of society
#      E005 Most important: first choice
#      E006 Most important: second choice
#      F194 How important: daily prayer
# -
#      A200 Social position: People in their 20s
#      A201 Social position: People in their 40s
#      A202 Social position: People in their 70s
#      E007 National goals: Maintaining order in the nation
#      E288 Social activism: Encouraging others to take action about political issues
# -
#      A203 Is a 30-year old boss acceptable
#      A207 Is a 70-year old boss acceptable
# -
#      A204 People over 70: are seen as friendly
#      A205 People over 70: are seen as competent
#      A206 People over 70: viewed with respect
# -
#      A208 Older people are not respected much these days
#      A209 Older people get more than their fair share from the government
#      A210 Older people are a burden on society
# -
#      A211 Companies that employ young people perform better than those that employ people of different ages
#      C025 Important in a job: meeting people
# -
#      A212 Old people have too much political influence
#      E205 Political parties serve the social and political needs of people
# -
#      A213 I see myself as someone who: is reserved
#      A214 I see myself as someone who: is generally trusting
#      A215 I see myself as someone who: tends to be lazy
#      A216 I see myself as someone who: is relaxed, handles stress well
#      A217 I see myself as someone who: has few artistic interests
#      A218 I see myself as someone who: is outgoing, sociable
#      A219 I see myself as someone who: tends to find fault with others
#      A220 I see myself as someone who: does a thorough job
#      A221 I see myself as someone who: gets nervous easily
#      A222 I see myself as someone who: has an active imagination
#      G019 I see myself as a world citizen
#      G020 I see myself as member of my local community
#      G022A I see myself as citizen of [Latinamerica]
#      G022B I see myself as citizen of [North America]
#      G022D I see myself as citizen of [APEC]
#      G022E I see myself as citizen of [ASIA]
#      G022F I see myself as citizen of [Mercosur]
#      G022H I see myself as citizen of [a country other than mine]
#      G022I I see myself as citizen of [CIS]
#      G022J I see myself as citizen of [The Caribbean]
#      G022M I see myself as citizen of [ASEAN]
#      G022N I see myself as citizen of [Arab Union]
#      G022P I see myself as citizen of the [UNASUR]
# -
#      B001 Would give part of my income for the environment
#      B004 Would buy things at a 20% higher price if it helped to protect environment
# -
#      B002 Increase in taxes if used to prevent environmental pollution
#      B003 Government should reduce environmental pollution
#      B012 Environmental action: recycle
# -
#      B005 All talk about the environment make people anxious
#      E140 Country cannot solve environmental problems by itself
# -
#      B006 Combatting unemployment, we have to accept environmental problems
#      E038 Job taking of the unemployed
# -
#      B007 Protecting environment and fighting pollution is less urgent than suggested
#      B008 Protecting environment vs. Economic growth
#      X003 Age
# -
#      B009 Human & nature
#      B017 Humanity has a bright or bleak future
# -
#      B010 [Country]s environmental problems can be solved without any international agreements to handle them
#      B018 Environmental problems in your community: Poor water quality.
#      B019 Environmental problems in your community: Poor air quality.
#      B020 Environmental problems in your community: Poor sewage and sanitation.
#      B021 Environmental problems in the world: Global warming or the greenhouse effect.
#      B022 Environmental problems in the world: Loss of plant or animal species or biodiversity.
#      B023 Environmental problems in the world: Pollution of rivers, lakes and oceans.
# -
#      B011 Environmental action: chosen products that are better for environment
#      B013 Environmental action: reduce water consumption
#      B014 Environmental action: attend meeting, signed petition
#      E222 Political action: Other
# -
#      B016 Tradition vs. high economic growth
# -
#      B030 Past two years: given money to ecological organization
#      B031 Past two years: participated in demonstration for environment
# -
#      C001 Jobs scarce: Men should have more right to a job than women (3 categories)
#      C001_01 Jobs scarce: Men should have more right to a job than women (5 categories)
#      C002 Jobs scarce: Employers should give priority to (nation) people than immigrants (3 categories)
#      C002_01 Jobs scarce: Employers should give priority to (nation) people than immigrants (5 categories)
#      C004 Jobs scarce: older people should be forced to retire
# -
#      C005 Unfair to give work to handicapped people when able bodied people can´t find jobs
#      E131 Why are people in need
#      G007_61 Trust: Canadian people in general
# -
#      C008 Work compared with Leisure
#      C041 Work should come first even if it means less spare time
# -
#      C009 First choice, if looking for a job
#      C010 Second choice if looking for a job
# -
#      C011 Important in a job: good pay
#      C012 Important in a job: not too much pressure
#      C013 Important in a job: good job security
#      C014 Important in a job: a respected job
#      C016 Important in a job: an opportunity to use initiative
#      C017 Important in a job: generous holidays
#      C018 Important in a job: that you can achieve something
#      C019 Important in a job: a responsible job
#      C020 Important in a job: a job that is interesting
#      C021 Important in a job: a job that meets one´s abilities
#      C022 Important in a job: pleasant people to work with
#      C024 Important in a job: a useful job for society
#      C027_90 Important in a job: none of these
#      E062 Importation of goods
# -
#      C031 Degree of pride in your work
#      E274 Frequency ordinary people pay a bribe, give a gift or do a favor to local officials/service providers in order to get services
# -
#      C034 Freedom decision taking in job
#      H008_08 Freedom and securiy - Which more important
# -
#      C036 To develop talents you need to have a job
#      E291 How much would you say the political system in your country allows people like you to have a say in what the government does?
# -
#      C037 Humiliating to receive money without having to work for it
#      D076 More than one wife
# -
#      C038 People who don´t work turn lazy
#      C040 People should not have to work if they don´t want to
#      C042B3 Why people work: I wouldn’t work if I didn’t have to
# -
#      C039 Work is a duty towards society
# -
#      C042B1 Why people work: work is like a business transaction
#      C042B2 Why people work: I do the best I can regardless of pay
#      C042B4 Why people work: I wouldn´t work if work interfered my life
#      C042B5 Why people work: work most important in my life
#      C042B6 Why people work: I never had a paid job
#      C042B7 Why people work: don’t know
# -
#      C059 Fairness: One secretary is paid more
#      E050 Personal characteristics: I serve as a model for others
# -
#      C061 Following instructions at work
#      E281 Which of the following problems does the organization Amnesty International deal with?
# -
#      C062 Work: until satisfied with results
# -
#      C063 Work: accomplish personal goals
# -
#      C064 Work: stay up late to finish
# -
#      COUNTRY_ALPHA ISO 3166-1 alpha-3 country code
#      COW_ALPHA CoW country code alpha
#      S003 ISO 3166-1 numeric country code
# -
#      COW_NUM CoW country code numeric
#      E001 Aims of country: first choice
#      E002 Aims of country: second choice
#      E240 Most serious problem for own country: 1st choice
#      E241 Most serious problem for own country: 2nd choice
# -
#      D001 How much do you trust your family
#      D001_B How much you trust: Your family (B)
#      G007_11 Trust: Yorubas
#      G007_17 Trust: Your friends
#      G007_31 Trust: Koreans
#      G007_63 Trust: Kurds
# -
#      D003 Sharing with partner: attitudes towards religion
#      D004 Sharing with partner: moral standards
#      D005 Sharing with partner: social attitudes
#      D006 Sharing with partner: political views
#      D007 Sharing with partner: sexual attitudes
#      D008 Sharing with partner: no sharing attitudes
#      D009 Sharing with partner: don´t know or missing
#      D010 Sharing with parents: attitudes towards religion
#      D011 Sharing with parents: moral standards´
#      D012 Sharing with parents: social attitudes
#      D013 Sharing with parents: political views
#      D014 Sharing with parents: sexual attitudes
#      D015 Sharing with parents: no sharing attitudes
# -
#      D016 Sharing with parents: don´t know or missing
# -
#      D017 Ideal number of children
#      H006_02 Worries: Not being able to give one's children a good education
# -
#      D018 Child needs a home with father and mother
#      D061 Pre-school child suffers with working mother
# -
#      D019 A woman has to have children to be fulfilled
#      D023 Woman as a single parent
# -
#      D022 Marriage is an out-dated institution
#      D043 Important for succesful marriage: Tastes and interests in common
#      S012 Date interview
# -
#      D024 Enjoy sexual freedom
#      E119 Government order vs. freedom
# -
#      D025 If only one child allowed: boy or girl
# -
#      D026_05 It is childs duty to take care of ill parent
#      X002 Year of birth
# -
#      D027 Important for succesful marriage: Faithfulness
#      D028 Important for succesful marriage: Adequate income
#      D029 Important for succesful marriage: Same social background
#      D031 Important for succesful marriage: Religious beliefs
#      D032 Important for succesful marriage: Good housing
#      D033 Important for succesful marriage: Agreement on politics
#      D034 Important in succesful marriage: Understanding and tolerance
#      D035 Important for succesful marriage: Apart from in-laws
#      D037 Important for succesful marriage: Sharing household chores
#      D038 Important for succesful marriage: Children
#      F032 Important: Religious service marriage
# -
#      D054 One of main goals in life has been to make my parents proud
#      D080 I decide my goals in life by myself
# -
#      D055 Make effort to live up to what my friends expect
# -
#      D056 Relationship working mother
#      E069_59 Confidence: Cooperation Council for the Arab states of Gulf (GCC)
#      G022R I see myself as part of the Cooperation Council for the Arab states of Gulf (GCC)
# -
#      D057 Being a housewife just as fulfilling
# -
#      D058 Husband and wife should both contribute to income
#      X047_WVS Scale of incomes
# -
#      D060 University is more important for a boy than for a girl
#      E235 Importance of democracy
# -
#      D063 Job best way for women to be independent
#      D063_B Job best way for women to be independent (b)
#      D072 Traits in a woman: Woman being independent
# -
#      D066 Problem if women have more income than husband (4 categories)
#      D066_01 Problem if women have more income than husband (5 categories)
#      D066_B Problem if women have more income than husband (3 categories)
#      F054 Believe in: heaven
# -
#      D067 Traits in a woman: Woman wearing weil
#      D068 Traits in a woman: Woman good mother
#      D069 Traits in a woman: Woman good wife
#      D070 Traits in a woman: Woman religious
#      D071 Traits in a woman: Woman educated
#      D073 Traits in a woman: Woman having work outside home
#      D074 Traits in a woman: Woman maintaining her family
#      D075 Traits in a woman: Woman being sociable
# -
#      D078 Men make better business executives than women do
#      G007_40 Trust: Chinese
# -
#      D079 I seek to be myself rather than to follow others
#      G027 Father immigrant
# -
#      D081 Homosexual couples are as good parents as other couples
# -
#      E003 Aims of respondent: first choice
#      E004 Aims of respondent: second choice
#      G027B Respondent citizen
#      S007 Unified respondent number
#      X025LIT Was the respondent literate
# -
#      E008 National goals: Giving people more say
#      E009 National goals: Fighting rising prices
#      E010 National goals: free speech
# -
#      E012 Willingness to fight for country
#      E127 Free market economy right for country future
#      E184 Aggression from neighbouring country
#      G005 Citizen of [country]
# -
#      E014 Future changes: Less emphasis on money and material possessions
#      E015 Future changes: Less importance placed on work
#      E016 Future changes: More emphasis on technology
#      E017 Future changes: More emphasis on individual
#      E018 Future changes: Greater respect for authority
#      E019 Future changes: More emphasis on family life
#      E020 Future changes: A simple and more natural lifestyle
# -
#      E022 Opinion about scientific advances
#      E211 Opinion about the problem of Palestine and Israel
#      E212 Opinion about 11th september airliners crash action by religious fundamentalists
# -
#      E023 Interest in politics
#      E033 Self positioning in political scale
#      E282 Political actions using Internet: Searching information about politics and political events
# -
#      E025 Political action: Signing a petition
#      E025B Political action recently done: signing a petition
#      E026 Political action: joining in boycotts
#      E026B Political action recently done: joining in boycotts
#      E028 Political action: joining unofficial strikes
#      E028B Political acition recently done: Joining strikes
#      E029 Political action: occupying buildings or factories
#      E222B Political action recently done: Other
#      E283 Political actions using Internet: Signing an electronic petition
#      E284 Political actions using Internet: Encouraging other people to take any form of political action
#      E285 Political actions using Internet: Organizing political activities, events, protests
# -
#      E027 Political action: attending lawful/peaceful demonstrations
#      E114 Political system: Having a strong leader
#      E116 Political system: Having the army rule
# -
#      E034 Basic kinds of attitudes concerning society
#      E192 Least liked group in society
# -
#      E035 Income equality
#      E233A Democracy: The state makes people's incomes equal
# -
#      E037 Government responsibility
#      E047 Personal characteristics: Changes, worry or welcome possibility
#      E053 Personal characteristics: I like to assume responsibility
# -
#      E039 Competition good or harmful
# -
#      E040 Hard work brings success
#      E048 Personal characteristics: I usually count on being successful in everything I do
# -
#      E041 Wealth accumulation
#      E069_62 Confidence: The World Health Organization (WHO)
# -
#      E045 Major changes in life
#      F009 Sorrow has meaning if you believe in God
# -
#      E046 New and old ideas
#      I001 One of the bad effects of science is that it breaks down people’s ideas of right and wrong
# -
#      E049 Personal characteristics: I enjoy convincing others of my opinion
#      E051 Personal characteristics: I am good at getting what I want
#      E052 Personal characteristics: I own many things others envy me for
#      E054 Personal characteristics: I am rarely unsure about how I should behave
#      E055 Personal characteristics: I often give others advice
#      E056 Personal characteristics: None of the above
# -
#      E057 The economic system needs fundamental changes
# -
#      E058 Our government should be made much more open to the public
#      F108 Government protects freedom
# -
#      E059 Allow more freedom for individuals
#      X003R Age recoded (6 intervals)
#      X003R2 Age recoded (3 intervals)
# -
#      E060 I could do nothing about an unjust law
#      F003 Thinking about death
# -
#      E061 Political reform is moving too rapidly
#      E111 Rate political system for governing country
#      E117 Political system: Having a democratic political system
# -
#      E063 Current society: Egalitarian vs. competitive society
#      E064 Current society: Extensive welfare vs. low taxes
#      E065 Current society: Regulated vs. responsible society
# -
#      E066 Society aimed:  egalitarian vs. competitive
#      E067 Society aimed: extensive welfare vs. low taxes
#      E068 Society aimed: regulated vs. responsible society
# -
#      E069_01 Confidence: Churches
#      E069_02 Confidence: Armed Forces
#      E069_03 Confidence: Education System
#      E069_04 Confidence: The Press
#      E069_05 Confidence: Labour Unions
#      E069_06 Confidence: The Police
#      E069_07 Confidence: Parliament
#      E069_08 Confidence: The Civil Services
#      E069_09 Confidence: Social Security System
#      E069_10 Confidence: Television
#      E069_11 Confidence: The Government
#      E069_13 Confidence: Major Companies
#      E069_18A Confidence: Major regional organization (combined from country-specific)
#      E069_19 Confidence: NATO
#      E069_21 Confidence: The Arab League
#      E069_24 Confidence: The NAFTA
#      E069_25 Confidence: The Andean pact
#      E069_26 Confidence: The Mercosur
#      E069_27 Confidence: The SAARC
#      E069_28 Confidence: The ECO
#      E069_29 Confidence: The APEC
#      E069_33 Confidence: Local/Regional Government
#      E069_38 Confidence: The Presidency
#      E069_40 Confidence: Charitable or humanitarian organizations
#      E069_41 Confidence: Banks
#      E069_42 Confidence: CARICOM
#      E069_43 Confidence: CIS
#      E069_47 Confidence: The American Forces
#      E069_49 Confidence: TV News
#      E069_52 Confidence: Evangelic Church
#      E069_57 Confidence: UNASUR
#      E069_60 Confidence: Mainland government
#      E069_63 Confidence: The World Bank
#      E069_64 Confidence: Elections
# -
#      E069_12 Confidence: The Political Parties
#      E069_14 Confidence: The Environmental Protection Movement
#      E069_15 Confidence: The Women´s Movement
#      E069_18 Confidence: The European Union
#      E069_20 Confidence: The United Nations
#      E069_31 Confidence: The United American States Organization (Organización de Estados Unidos Americanos - OEA)
#      E069_39 Confidence: The Civil Society Groups
#      E069_48 Confidence: The non-Iraqi television
#      E069_54 Confidence: Universities
#      E069_56 Confidence: The Organization of American States (OAE)
#      E069_58 Confidence: The Arab Maghreb Union
#      E069_61 Confidence: The World Trade Organization (WTO)
#      E069_67 Confidence: The African Union (AU)
# -
#      E069_17 Confidence: Justice System/Courts
#      E069_34 Confidence: SADC/SADEC
#      E069_35 Confidence: East African Cooperation (EAC)
# -
#      E069_22 Confidence: The Association of South East Asian Nations -ASEAN
#      E069_23 Confidence: The Organization for African Unity-OAU
#      E069_51 Confidence: Religious leaders
#      E069_55 Confidence: The Organization of the Islamic World
# -
#      E069_30 Confidence: The Free Commerce Treaty (Tratado de libre comercio)
#      E069_32 Confidence: The “Movimiento en pro de Vieques”(Puerto Rico)
# -
#      E069_44 Confidence: Confidence in CER with Australia
# -
#      E069_45 Confidence: International Monetary Found (IMF)
#      E069_46 Confidence: Non governmental Organizations (NGOs)
#      E069_65 Confidence: International Criminal Court (ICC)
# -
#      E069_66 Confidence: UNDP United Nations Development Programme
#      E237 Heard of the Millennium Development Goals
# -
#      E104 Approval: Ecology movement or nature protection
#      E105 Approval: Anti-nuclear energy movement
#      E109 Approval: Anti-apartheid movement
# -
#      E106 Approval: Disarmament movement
#      E107 Approval: Human rights movement
#      E108 Approval: Women’s movement
# -
#      E110 Satisfaction with the way democracy develops
#      E267 Importance of having honest elections in whether or not this country develops economically
# -
#      E115 Political system: Having experts make decisions
#      E117B Political system: Having a system governed by religious law in which there are no political parties or elections
# -
#      E118 Firm party leader vs. Cooperating party leader
# -
#      E120 In democracy, the economic system runs badly
#      E214 Western democracy is the best political system for country
# -
#      E121 Democracies are indecisive and have too much squabbling
# -
#      E122 Democracies aren´t good at maintaining order
# -
#      E123 Democracy may have problems but is better
#      E231 Democracy: Criminals are severely punished.
# -
#      E124 Respect for individual human rights nowadays
#      E139 Who should decide: human rights
# -
#      E128 Country is run by big interest vs. for all people’s benefit
#      F110 Laws: people’s wishes
# -
#      E129 Economic aid to poorer countries
#      E129D Economic aid to poorer countries (favor/against)
#      F176 Some US Policies toward other countries are good and some are bad
# -
#      E129A Amount of foreign aid of this country
#      E134 Amount of help for less developed countries
# -
#      E129C Be willing to pay higher taxes in order to increase country´s foreign aid
#      G007_01 Trust: Other people in country
#      G018 When came to country
# -
#      E130 Poverty compared to 10 years ago
# -
#      E132 Chance to escape from poverty
#      E242 MDG: Reduce extreme poverty
# -
#      E133 How much is the government doing against poverty
#      G016 Language at home
# -
#      E135 Who should decide: international peacekeeping
#      E136 Who should decide: protection of the environment
#      E137 Who should decide: aid to developing countries
#      E138 Who should decide: refugees
# -
#      E141 Country cannot solve crime problems by itself
#      E142 Country cannot solve employment problems by itself
# -
#      E143 Immigrant policy
#      E209 Would persist to immigrate abroad if R´s economic situation was better
# -
#      E150 How often follows politics in the news
#      E255 How often use of PC
#      F028B How often to you pray
# -
#      E179_WVS7LOC Which party would you vote for if there were a national election tomorrow (Local names)
#      E179WVS Which party would you vote for: first choice (WVS)
#      E180WVS Which party would you vote for: second choice (WVS)
#      E182 Party that would never vote
# -
#      E185 Exploitation of local resources
#      E203 Rapid implementation of market reforms have negative impact on national stability
# -
#      E186 Cultural invasion by the west
# -
#      E188 Frequency watches TV
#      H008_05 How frequently do the following things occur in your neighborhood: Street violence and fights
#      H008_06 How frequently do the following things occur in your neighborhood: Sexual harassment
# -
#      E189 TV most important entertainment
#      G026 Mother immigrant
#      I002 It is not important for me to know about science in my daily life
# -
#      E190 Why are there people living in need: first
#      E191 Why are there people living in need: second
#      F055 Believe in: Sin
# -
#      E193 Least liked allow: hold office
#      E194 Least liked allow: teach
#      E195 Least liked allow: demonstrate
# -
#      E196 Extent of political corruption
#      E198 Using violence for political goals not justified
# -
#      E204 Effect of market economic reforms
# -
#      E206 Free and fair elections will reduce terrorism
#      E263 Vote in elections: local level
# -
#      E207 [Country] should have close relations with France
#      E208 [Country] should have close relations with United States
#      F172 A truly Islamic country should not have a parliament with the right to pass laws
# -
#      E213 Woman should not work outside unless forced to do so
# -
#      E215 It is necessary to fight terrorism by military means
#      F186 Religion is a cause of terrorism
# -
#      E216 [Country] needs foreign military cooperation to combat terrorism
# -
#      E217 Science and technology are making our lives healthier, easier, and more comfortable
#      E219 Science and technology make our way of life change too fast
# -
#      E218 Because of science and technology, there will be more opportunities for the next generation
# -
#      E220 We depend too much on science and not enough on faith
#      F010 Life has no meaning
# -
#      E221B Political action recently done: Attending peaceful/lawful demonstrations
# -
#      E224 Democracy: Governments tax the rich and subsidize the poor.
#      E233 Democracy: Women have the same rights as men.
#      E233B Democracy: People obey their rulers
# -
#      E225 Democracy: Religious authorities interpret the laws.
#      E226 Democracy: People choose their leaders in free elections.
# -
#      E227 Democracy: People receive state aid for unemployment.
#      E232 Democracy: People can change the laws in referendums.
#      G007_57 Trust: Poles
# -
#      E228 Democracy: The army takes over when government is incompetent.
#      E230 Democracy: The economy is prospering.
#      F168 Democracy is a Western form of government that is not compatible with Islam
# -
#      E229 Democracy: Civil rights protect people’s liberty against oppression.
# -
#      E234 The world is better off, or worse off, because of science and technology
# -
#      E236 Democraticness in own country
#      E268 Scale corruption in [my country] - pay a bribe, give a gift, do a favor to other to get things
# -
#      E238 Most serious problem of the world: 1st choice
#      E239 Most serious problem of the world: 2nd choice
# -
#      E243 MDG: Increase primary education
#      S013B Interview privacy
# -
#      E244 MDG: Reduce child mortality
#      Y021C Welzel autonomy-3: Obedience as kid quality
# -
#      E245 MDG: Fight HIV
#      F141 Justifiable: Fighting with the police
# -
#      E246 MDG: Improve housing conditions
# -
#      E247 Priority: Global poverty versus National problems
#      F198 Fate versus control
# -
#      E248 Information source: Daily newspaper
#      E248B Information source: Daily newspaper (B)
#      E249 Information source: News broadcasts on radio or TV
#      E250 Information source: Printed magazines
#      E250B Information source: Printed magazines (B)
#      E251 Information source: In depth reports on radio or TV
#      E252 Information source: Books
#      E253 Information source: Internet, Email
#      E253B Information source: Social media (Facebook, Twitter, etc.)
#      E254 Information source: Talk with friends or colleagues
#      E254B Information source: Talk with friends or colleagues (B)
#      E258 Information source: TV news
#      E258B Information source: TV news (B)
#      E259 Information source: Radio news
#      E259B Information source: Radio news (B)
#      E260 Information source: Mobile phone
#      E260B Information source: Mobile phone (B)
#      E261 Information source: Email
#      E261B Information source: Email (B)
#      E262 Information source: Internet
#      E262B Information source: Internet (B)
# -
#      E256 General party preference
# -
#      E257 Voted in recent parliament elections
#      E265_01 How often in country's elections: Votes are counted fairly
#      E265_02 How often in country's elections: Opposition candidates are prevented from running
#      E265_03 How often in country's elections: TV news favors the governing party
#      E265_04 How often in country's elections: Voters are bribed
#      E265_05 How often in country's elections: Journalists provide fair coverage of elections
#      E265_06 How often in country's elections: Election officials are fair
#      E265_07 How often in country's elections: Rich people buy elections
#      E265_08 How often in country's elections: Voters are threatened with  violence at the polls
#      E265_09 How often in country's elections: Voters are offered a genuine choice in the elections
#      E265_10 How often in country´s elections: Women have equal opportunities to run the office
# -
#      E264 Vote in elections: National level
#      W002D Country specific: Education level partner
# -
#      E266 Some people think that having honest elections makes a lot of difference in their lives;  other people think that it doesn’t matter much
#      F114D Justifiable: Violence against other people
# -
#      E269 Groups of people involved in corruption: State authorities
#      E270 Groups of people involved in corruption: Business executives
#      E271 Groups of people involved in corruption: Local authorities
#      E272 Groups of people involved in corruption: Civil service providers (police, judiciary, civil servants, doctors, teachers)
#      E273 Groups of people involved in corruption: Journalists and media
#      X013 Number of people in household
# -
#      E275 Degree of agreement: On the whole, women are less corrupt than men
#      F206 Degree of agreement: Nowadays one often has trouble deciding which moral rules are the right ones to follow
# -
#      E276 Risk in this country to be held accountable for giving or receiving a bribe, gift or favor in return for public service
#      F117 Justifiable: Someone accepting a bribe
#      F125 Justifiable: Joyriding
# -
#      E277 Standard of living comparing with your parents
#      X026 Do you live with your parents
# -
#      E278 Should international organizations prioritize, being effective or being democratic
# -
#      E279 Five countries have permanent seats on the Security Council of the United Nations. Which ones of the following is not a member?
#      F111 Only laws of the Shari´a
# -
#      E280 Where are the headquarters of the International Monetary Fund (IMF) located?
#      S011A Time of the interview - Start
# -
#      E286 Social activism: Donating to a group or campaign
#      E287 Social activism: Contacting a government official
#      E289 Social activism: Encouraging others to vote
# -
#      E290 Justifiable: Political violence
#      F114A Justifiable: Claiming government benefits to which you are not entitled
#      F114B Justifiable: Stealing property
#      F115 Justifiable: Avoiding a fare on public transport
#      F116 Justifiable: Cheating on taxes
#      F118 Justifiable: Homosexuality
#      F119 Justifiable: Prostitution
#      F120 Justifiable: Abortion
#      F121 Justifiable: Divorce
#      F122 Justifiable: Euthanasia
#      F123 Justifiable: Suicide
#      F124 Justifiable: Drinking alcohol
#      F127 Justifiable: Llying
#      F128 Justifiable: Adultery
#      F129 Justifiable: Throwing away litter
#      F132 Justifiable: Having casual sex
#      F136 Justifiable: Political assassination
#      F144_02 Justifiable: Death penalty
#      F199 Justifiable: For a man to beat his wife
# -
#      F001 Thinking about meaning and purpose of life
# -
#      F004 Life is meaningful because God exits
#      F007 Death has meaning if you believe in God
# -
#      F005 Try to get the best out of life
#      F036 Churches give answers: the problems of family life
# -
#      F006 Death is inevitable
#      F008 Death is a natural resting point
# -
#      F022 Statement: good and evil
#      F048 Churches speak out on: ecology and environmental issues
# -
#      F024 Belong to religious denomination
#      F025 Religious denominations - major groups
#      F025_WVS Religious denomination - detailed list
#      F027 Which former religious denomination
# -
#      F028 How often do you attend religious services
#      F029 Raised religiously
#      F031 Important: Religious service birth
#      F033 Important: Religious service death
#      F066 Pray to God outside of religious services (I)
#      F067 Pray to God outside of religious services (ii)
# -
#      F035 Churches give answers: moral problems
#      F037 Churches give answers: people´s spiritual needs
#      F038 Churches give answers: the social problems
# -
#      F040 Churches speak out on: disarmament
#      F041 Churches speak out on: abortion
#      F042 Churches speak out on: third world problems
#      F043 Churches speak out on: extramarital affairs
#      F044 Churches speak out on: unemployment
#      F045 Churches speak out on: racial discrimination
#      F046 Churches speak out on: euthanasia
#      F047 Churches speak out on: homosexuality
#      F049 Churches speak out on: government policy
# -
#      F050 Believe in: God
#      F051 Believe in: life after death
#      F052 Believe in: people have a soul
#      F057 Believe in: re-incarnation
#      F059 Believe in: devil
# -
#      F060 Believe in: resurrection of the dead
# -
#      F062 Personal God vs. Spirit or Life Force
# -
#      F063 How important is God in your life
#      F188 Which is more important as a basis for marriage:  parents´ approval or love
# -
#      F064 Get comfort and strength from religion
#      F109 Government protects religion
# -
#      F065 Moments of prayer, meditation...
#      F187 The content of [Country] education contributes to religious extremism
# -
#      F102 Politicians who don´t believe in God are unfit for public office
# -
#      F103 Religious leaders should not influence how people vote
#      F105 Religious leaders should not influence government
# -
#      F104 Better if more people with strong religious beliefs in public office
# -
#      F114E Justifiable: Terrorism as a political, ideological or religious mean
#      F126 Justifiable: Taking soft drugs
#      F135A Justifiable: Sex before marriage
# -
#      F130 Justifiable: Driving under influence of alcohol
#      F135 Justifiable: Sex under the legal age of consent
# -
#      F139 Justifiable: Buy stolen goods
#      F140 Justifiable: Keeping money that you have found
#      F142 Justifiable: Failing to report damage you’ve done accidentally to a parked vehicle
#      F144 Justifiable: Klling in self-defence
# -
#      F143 Justifiable: Threatening workers who refuse to join a strike
# -
#      F164 Islam requires woman to dress modestly but does not require cover face with veil
# -
#      F165 Violation of Islam for male and female university students to attend classes together
#      G032 Ethnic diversity
# -
#      F166 By requiring man treat all wives equally, Islam true intent is prohibit taking more than one wife
# -
#      F167 Monarchy is a form of government that is compatible with Islam
# -
#      F169 Nationalism is incompatible with Islam because Islam requires ´ummah´
# -
#      F170 If Palestinian state established and peace with Israel, Islam would not oppose existence of Israel
# -
#      F171 If country pursues policies harmful to Muslims, Islam permits killing civilians in that country
# -
#      F173 Islam requires that political rights of non Muslims should be inferior to those of Muslims
#      F174 Islams requires country with majority of Muslims be governed by men of Islamic learning
# -
#      F175 Religions limit democratic processes
# -
#      F177 While US policies toward other countries are often bad, most ordinary americans are good people
#      G007_08 Trust: Central Americans
#      G007_37 Trust: Americans
#      G007_42 Trust: Latin Americans
# -
#      F178 The culture of US and other Western countries has many positive attributes
#      F179 Exposure to the culture of the US and other Western countries harmful effect on our country
#      S011B Time at the end of interview
# -
#      F189 When you were growing up, did your father or mother have more influence in the affairs of the house
# -
#      F190 How frequently do you perform the five prescribed prayers of the Islam
#      F191 How frequently do you perform in the mosque
# -
#      F192 If you feel sad and want to talk to someone, to whom do you usually turn to
# -
#      F193 Civil marriage is very important because it helps maintain the family
# -
#      F195 How important: building a prosperous society
#      F196 How important: forming a happy secure family
#      F197 How important: building a successful professional future
# -
#      F200 Meaning of religion: To follow religious norms and ceremonies vs To do good to other people
# -
#      F201 Meaning of religion: To make sense of life after death vs To make sense of life in this world
#      X010 Where r lived after married
# -
#      F202 Whenever science and religion conflict,  religion is always right
#      F203 The only acceptable religion  is my religion
# -
#      F204 All religions should be taught in public schools
# -
#      F205 People who belong to different religions are probably just as moral as those who belong to mine
# -
#      G001 Geographical groups belonging to first
#      G001CS Geographical groups belonging to first (country specific)
#      G002 Geographical groups belonging to second
#      G002CS Geographical groups belonging to second  (country specific)
#      G003CS Geographical groups belonging to least of all (country specific)
# -
#      G006 How proud of nationality
#      G007_36_B Trust: People of another nationality (B)
# -
#      G007_02 Trust: French Canadians
#      G007_03 Trust: Nepalis
#      G007_04 Trust: Korean residents in Japan
#      G007_06 Trust: Mestizo
#      G007_07 Trust: Indians
#      G007_10 Trust: Igbos
#      G007_12 Trust: Ghanaians
#      G007_28 Trust: Moroccans
#      G007_44 Trust: Blacks
#      G007_45 Trust: Germans
#      G007_49 Trust: Pascuences
#      G007_62 Trust: Christians
#      G007_65 Trust: Relatives
#      G007_66 Trust: Shi´i
#      G007_67 Trust: Sunni
# -
#      G007_05 Trust: Chinese residents in Japan
#      G007_09 Trust: Hausas
#      G007_13 Trust: Czechs
#      G007_16 Trust: West Germans
#      G007_43 Trust: Japanese
#      G007_51 Trust: Peruvians
#      G007_52 Trust: Chinese Zhuan Nationality
#      G007_54 Trust: English
#      G007_56 Trust: Gypsies
#      G007_60 Trust: Pakistanis
# -
#      G007_18 Trust: Your neighborhood
#      G007_18_B Trust: Your neighborhood (B)
#      G007_30 Trust: Portuguese
#      G007_55 Trust: Slovaks
# -
#      G007_19 Trust: White South Africans
#      G007_20 Trust: Black South Africans
#      G007_21 Trust: Coloured South Africans
#      G007_22 Trust: Asian South Africans
# -
#      G007_32 Trust: Soviet Union people
#      G007_33_B Trust: People you know personally (B)
#      G007_64 Trust: People in general
# -
#      G007_34_B Trust: People you meet for the first time (B)
#      G007_35_B Trust: People of another religion (B)
# -
#      G007_39 Trust: Russians
#      G007_41 Trust: Italians
#      G007_53 Trust: Chinese Hui Nationality
#      G007_58 Trust: Indian Hindus
# -
#      G007_48 Trust: Mapuche Indians
#      G007_59 Trust: Indian Non-Hindus
# -
#      G007_50 Confianza: Argentinos
# -
#      G015 Which of the following best describes you
#      G015B Which of the following best describes you (B)
#      G061 People from other countries coming here to work - Which of the following the government should do
# -
#      G017 Born in this country: birth country
#      G054 Effects of immigrants on the development of [your country]: Strengthen cultural diversity
# -
#      G021 I see myself as citizen of the [country] nation
#      G022C I see myself as citizen of the [European Union]
#      G022G I see myself as citizen of [my province or region]
#      G022K I see myself as citizen of [The African Union]
#      G022L I see myself as citizen of [Arab Maghreb Union]
#      G022O I see myself as citizen of the [Northeast Asia Region]
#      G022Q I see myself as citizen of the [Islamic nation]
# -
#      G023 I see myself as an autonomous individual
#      Y003 Autonomy Index
# -
#      G024 What thing are you proud of in your country -1st
#      G025 What thing are you proud of in your country -2nd
# -
#      G026_01 Mother's Country of origin
#      G027_01 Father's Country of origin
#      V001A Fathers country of birth - ISO 3166-1 code
#      V002A Mothers country of birth - ISO 3166-1 code
# -
#      G027A Respondent immigrant
#      G052 Evaluate the impact of immigrants on the development of [your country]
#      G053 Effects of immigrants on the development of [your country]: Fill useful jobs in the workforce
#      G055 Effects of immigrants on the development of [your country]: Increase the crime rate
#      G056 Effects of immigrants on the development of [your country]: Give asylum to political refugees
#      G057 Effects of immigrants on the development of [your country]: Increase the risks of terrorism
#      G058 Effects of immigrants on the development of [your country]: Help poor people establish new lives
#      G059 Effects of immigrants on the development of [your country]: Increase unemployment
#      G060 Effects of immigrants on the development of [your country]: Lead to social conflict
# -
#      G028 Requirements for citizenship: having ancestors from my country
#      G029 Requirements for citizenship: being born on my country’s soil
#      G030 Requirements for citizenship: adopting the customs of my country
#      G031 Requirements for citizenship: abiding by my country´s laws
# -
#      G062 How close you feel: Continent; e.g. Europe, Asia etc.]
#      G063 How close you feel: World
#      G255 How close you feel: Your [village, town or city]
# -
#      H001 Secure in neighborhood
#      H002_01 Frequency in your neighborhood: Robberies
#      H002_02 Frequency in your neighborhood: Alcohol consumed in the streets
#      H002_03 Frequency in your neighborhood: Police or military interfere with people’s private life
#      H002_04 Frequency in your neighborhood: Racist behavior
#      H002_05 Frequency in your neighborhood: Drug sale in streets
# -
#      H003_01 Things done for reasons of security: Didn’t carry much money
#      H003_02 Things done for reasons of security: Preferred not to go out at night
#      H003_03 Things done for reasons of security: Carried a knife, gun or other weapon
# -
#      H004 Respondent was victim of a crime during the past year
#      H005 Respondent's family was victim of a crime during last year
#      X024B Respondent - literate
# -
#      H006_01 Worries: Losing my job or not finding a job
#      H006_03 Worries: A war involving my country
# -
#      H006_04 Worries: A terrorist attack
#      H006_05 Worries: A civil war
# -
#      H006_06 Worries: Government wire-tapping or reading my mail or email
# -
#      H007 Under some conditions, war is necessary to obtain justice
# -
#      H008_01 Frequency you/family (last 12 month): Gone without enough food to eat
#      H008_02 Frequency you/family (last 12 month): Felt unsafe from crime in your own home
#      H008_03 Frequency you/family (last 12 month): Gone without needed medicine or treatment that you needed
#      H008_04 Frequency you/family (last 12 month): Gone without a cash income
# -
#      H008_07 Freedom and Equality - Which more important
# -
#      H008_09 In the last 12 month, how often have you or your family: Gone without a safe shelter over your head
# -
#      H009 Government has the right: Keep people under video surveillance in public areas
#      H010 Government has the right: Monitor all e-mails and any other information exchanged on the Internet
#      H011 Government has the right: Collect information about anyone living in [COUNTRY] without their knowledge
# -
#      MODE Mode of data collection
# -
#      S002VS Chronology of EVS-WVS waves
# -
#      S006 Original respondent number
#      V004AF_01 Highest educational level attained - Respondent´s Father ISCED
#      V004AM_01 Highest educational level attained - Respondent´s Mother ISCED
#      V004RF Highest educational level attained - Respondent´s Father (Recoded)
#      V004RM Highest educational level attained - Respondent´s Mother (Recoded)
#      W002A_01 Highest educational level attained - Respondent´s Spouse ISCED
# -
#      S010 Total length of interview
#      S013 Respondent interested during the interview
# -
#      S016 Language of the interview (WVS/EVS list of languages)
#      S016B Language in which interview was conducted
# -
#      S018 Equilibrated weight-1000
# -
#      S020 Year survey
# -
#      S021 Country - wave - study - set - year
# -
#      S022 Year/month of start-fieldwork
#      S023 Year/month of end-fieldwork
# -
#      V097EF Respondent´s Father - Occupational group (when respondent was 14 years old) (WVS)
#      W006E Respondent´s Spouse - Occupational group (WVS)
#      X036E Respondent - Occupational group (WVS)
# -
#      W002R educational level partner (recoded)
#      X025 Highest educational level attained
#      X025A_01 Highest educational level attained - Respondent ISCED-2011
#      X025R Education level (recoded)
# -
#      W003 Employment status - Responent´s Spouse
#      X007 Marital status
#      X028 Employment status
# -
#      X002_02A Respondents country of birth - ISO 3166-1 code
#      X048ISO Region ISO 3166-2
# -
#      X008 Have you been married before
# -
#      X011 How many children do you have
# -
#      X012 How many are still living at home
# -
#      X023 What age did you complete your education
#      X023R What age did you complete your education (recoded in intervals)
# -
#      X025CSWVS Education (country specific)
#      X047CS Scale of incomes (Country specific)
#      X049CS Settlement size (country specific)
# -
#      X031 Are you supervising someone
# -
#      X036 Profession/job
#      X043 Chief wage earner profession/job
# -
#      X040 Are you the chief wage earner in your house
#      X041 Is the chief wage earner employed now
# -
#      X044 Family savings during past year
# -
#      X047R_WVS Subjective income level (recoded in 3 groups)
# -
#      X048WVS Region where the interview was conducted (WVS)
#      X050B Settlement type where interview was conducted
# -
#      X049 Settlement size
# -
#      X050 Type of habitat
# -
#      X050C Urban/Rural habitat
# -
#      X052 Institution of occupation
# -
#      X053 Nature of tasks: manual vs. Cognitive
#      X054 Nature of tasks: routine vs. Creative
#      X055 Nature of tasks: independence
# -
#      Y001 Post-Materialist index 12-item
#      Y002 Post-Materialist index 4-item
# -
#      Y010 Welzel Overall Secular Values
#      Y024A Welzel voice-1
#      Y024B Welzel voice-2
# -
#      Y011 Welzel defiance sub-index
#      Y011A AUTHORITY - Welzel defiance - 1: Inverse respect for authority
#      Y011B NATIONALISM - Welzel defiance - 2: Inverse national pride
#      Y011C Welzel defiance - 3: Inverse devoutness
#      Y012 Welzel disbelief sub-index
#      Y023 Welzel choice sub-index
# -
#      Y012A RELIGIMP - Welzel 1: Inverse importance of religion
#      Y012B RELIGBEL - Welzel 2: Inverse religious person
#      Y012C RELIGPRAC - Welzel 3: Inverse religious practice
#      Y013A NORM1 - Welzel 1: Inverse norm conform1
#      Y013B NORM2 - Welzel 2: Inverse norm conform2
#      Y013C NORM3 - Welzel 3: Inverse norm conform3
#      Y014A Welzel 1: Inverse trust in army
#      Y014B Welzel 2: Inverse trust in police
#      Y014C Welzel 3: Inverse trust in courts
# -
#      Y013 Welzel relativism
#      Y014 Welzel scepticism index
#      Y021A Welzel autonomy-1: Independence as kid quality
#      Y022 Welzel equality sub-index
# -
#      Y020 Welzel emancipative values
# -
#      Y021 Wezel Autonomy subindex
#      Y021B Welzel autonomy-2: Imagination as kid quality
# -
#      Y022A Welzel equality-1: Gender equality: job
#      Y022B Welzel equality-2: Gender equality: politics
#      Y022C Welzel equality-3: Gender equality: education
# -
#      Y023A Welzel choice-1: Homosexuality acceptance
#      Y023B Welzel choice-2: Abortion acceptable
#      Y023C Welzel choice-3: Divorce acceptable
#      Y024 Welzel voice sub-index
# -
#      Y024C Welzel voice-3 (auxiliary)

# %%
# III. Prepare WVS dataset

# A) read country, year and selected variables in chunks

wvs_keepVars = ['A001', 'A002', 'A003', 'A004', 'A005', 'A006', 'A008', 'E114', 'E117']

wvs_countryVar = 'S003'
wvs_yearVar = 'S020'
wvs_countryYear = pd.DataFrame(columns = [wvs_countryVar, wvs_yearVar]).astype({(wvs_yearVar): np.uint16})
wvs_varData = pd.DataFrame(columns = wvs_keepVars).astype(np.float16)

chunksize = 2000
with pd.read_csv('../0_datasets/wvs.csv', sep=';', na_values=['', ' '], chunksize=chunksize) as reader:
    for chunk in reader:
        wvs_countryYear = pd.concat([wvs_countryYear, chunk[[wvs_countryVar, wvs_yearVar]]]).astype({(wvs_yearVar): np.uint16})
        wvs_varData = pd.concat([wvs_varData, chunk[wvs_keepVars]]).astype(np.float16)

wvs_varData
# Out:
#         A001  A002  A003  A004  A005  A006  A008  E114  E117
# 0        1.0   2.0   2.0   4.0   2.0   2.0   3.0   3.0   1.0
# 1        1.0   2.0   2.0   3.0   2.0   2.0   2.0   3.0   2.0
# 2        1.0   2.0   2.0   4.0   1.0   1.0   3.0   2.0   1.0
# 3        1.0   2.0   2.0   3.0   2.0   2.0   3.0   2.0   1.0
# 4        1.0   2.0   2.0   4.0   1.0   1.0   3.0  -2.0   1.0
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...
# 440050   1.0   3.0   1.0   1.0   1.0   2.0   2.0   1.0   1.0
# 440051   1.0   1.0   2.0   1.0   1.0   1.0   2.0   4.0   1.0
# 440052   1.0   3.0   2.0   2.0   2.0   2.0   3.0   3.0   1.0
# 440053   1.0   2.0   2.0   1.0   1.0   1.0   4.0   1.0   2.0
# 440054   1.0   2.0   2.0   2.0   1.0   1.0   3.0   3.0   1.0
#
# [440055 rows x 9 columns]

# %%
# B) normalize data by min-max normalization

wvs_varData_norm = wvs_varData.copy()
wvs_varData_norm[wvs_varData.lt(0)] = np.nan # filter out (negative) marker values

for col in wvs_varData.columns:
    wvs_varData_norm[col] = (wvs_varData_norm[col] - wvs_varData_norm[col].min()) / (wvs_varData_norm[col].max() - wvs_varData_norm[col].min())
    wvs_varData_norm[col] = 1 - wvs_varData_norm[col]
    
# C) concat country+year+variable columns, also replace variable titles
wvs = pd.concat([wvs_countryYear, wvs_varData_norm], axis=1)

wvs.rename(columns=wvs_vars.loc[wvs.columns]['Title'], inplace=True)
wvs.rename(columns={'ISO 3166-1 numeric country code': 'Country', 'Year survey': 'Year'}, inplace=True)

wvs
# Out:
#        Country  Year  Important in life: Family  Important in life: Friends  \
# 0            8  1998                        1.0                    0.666992
# 1            8  1998                        1.0                    0.666992
# 2            8  1998                        1.0                    0.666992
# 3            8  1998                        1.0                    0.666992
# 4            8  1998                        1.0                    0.666992
# ...        ...   ...                        ...                         ...
# 440050     716  2020                        1.0                    0.333496
# 440051     716  2020                        1.0                    1.000000
# 440052     716  2020                        1.0                    0.333496
# 440053     716  2020                        1.0                    0.666992
# 440054     716  2020                        1.0                    0.666992
#
#         Important in life: Leisure time  Important in life: Politics  \
# 0                              0.666992                     0.000000
# 1                              0.666992                     0.333496
# 2                              0.666992                     0.000000
# 3                              0.666992                     0.333496
# 4                              0.666992                     0.000000
# ...                                 ...                          ...
# 440050                         1.000000                     1.000000
# 440051                         0.666992                     1.000000
# 440052                         0.666992                     0.666992
# 440053                         0.666992                     1.000000
# 440054                         0.666992                     0.666992
#
#         Important in life: Work  Important in life: Religion  \
# 0                      0.666992                     0.666992
# 1                      0.666992                     0.666992
# 2                      1.000000                     1.000000
# 3                      0.666992                     0.666992
# 4                      1.000000                     1.000000
# ...                         ...                          ...
# 440050                 1.000000                     0.666992
# 440051                 1.000000                     1.000000
# 440052                 0.666992                     0.666992
# 440053                 1.000000                     1.000000
# 440054                 1.000000                     1.000000
#
#         Feeling of happiness  Political system: Having a strong leader  \
# 0                   0.333496                                  0.333496
# 1                   0.666992                                  0.333496
# 2                   0.333496                                  0.666992
# 3                   0.333496                                  0.666992
# 4                   0.333496                                       NaN
# ...                      ...                                       ...
# 440050              0.666992                                  1.000000
# 440051              0.666992                                  0.000000
# 440052              0.333496                                  0.333496
# 440053              0.000000                                  1.000000
# 440054              0.333496                                  0.333496
#
#         Political system: Having a democratic political system
# 0                                                1.000000
# 1                                                0.666992
# 2                                                1.000000
# 3                                                1.000000
# 4                                                1.000000
# ...                                                   ...
# 440050                                           1.000000
# 440051                                           1.000000
# 440052                                           1.000000
# 440053                                           0.666992
# 440054                                           1.000000
#
# [440055 rows x 11 columns]

# %%
# D) convert from wide into long format

wvs = wvs.melt(id_vars=['Year', 'Country'], var_name='Variable', value_name='Value')

wvs.head()
# Out:
#    Year Country                   Variable  Value
# 0  1998       8  Important in life: Family    1.0
# 1  1998       8  Important in life: Family    1.0
# 2  1998       8  Important in life: Family    1.0
# 3  1998       8  Important in life: Family    1.0
# 4  1998       8  Important in life: Family    1.0

# %%
# E) summarize data by taking arithmetic mean

wvsSummary = wvs.groupby(['Year', 'Country', 'Variable']).mean().reset_index()
wvs = None # free memory
wvsSummary.head()
# Out:
#    Year  Country                         Variable     Value
# 0  1981       36             Feeling of happiness  0.768555
# 1  1981       36        Important in life: Family       NaN
# 2  1981       36       Important in life: Friends       NaN
# 3  1981       36  Important in life: Leisure time       NaN
# 4  1981       36      Important in life: Politics       NaN

# %%
# IV. Prepare country-codes.csv

# A) read dataset
countryCodes = pd.read_csv('../0_datasets/country-codes.csv')
countryCodes.head()
# Out:
#              name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0     Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1   Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2         Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3         Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4  American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
#
#         sub-region intermediate-region  region-code  sub-region-code  \
# 0    Southern Asia                 NaN        142.0             34.0
# 1  Northern Europe                 NaN        150.0            154.0
# 2  Southern Europe                 NaN        150.0             39.0
# 3  Northern Africa                 NaN          2.0             15.0
# 4        Polynesia                 NaN          9.0             61.0
#
#    intermediate-region-code
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
# B) set iso 3166-2 code as index to country name

countryCodes = countryCodes[['name', 'country-code']].set_index('country-code')
countryCodes.head()
# Out:
#                         name
# country-code
# 4                Afghanistan
# 248            Åland Islands
# 8                    Albania
# 12                   Algeria
# 16            American Samoa

# %%
# C) replace country codes with country names in WVS Summary

wvsSummaryCC = wvsSummary.copy()
wvsSummaryCC['Country'] = countryCodes.loc[wvsSummary['Country']]['name'].values
wvsSummaryCC = wvsSummaryCC.loc[wvsSummaryCC['Country'].isin(countriesOfInterest)]
wvsSummaryCC = pd.concat([wvsSummaryCC, cpi_norm], axis=0)
wvsSummaryCC
# Out:
#       Year                   Country                         Variable  \
# 63    1982              South Africa             Feeling of happiness
# 64    1982              South Africa        Important in life: Family
# 65    1982              South Africa       Important in life: Friends
# 66    1982              South Africa  Important in life: Leisure time
# 67    1982              South Africa      Important in life: Politics
# ...    ...                       ...                              ...
# 3928  2015                     Egypt      Corruption Perception Index
# 3941  2015                   Germany      Corruption Perception Index
# 4024  2015        Russian Federation      Corruption Perception Index
# 4044  2015              South Africa      Corruption Perception Index
# 4076  2015  United States of America      Corruption Perception Index
#
#          Value
# 63    0.682617
# 64         NaN
# 65         NaN
# 66         NaN
# 67         NaN
# ...        ...
# 3928  0.360000
# 3941  0.810000
# 4024  0.290000
# 4044  0.440000
# 4076       NaN
#
# [603 rows x 4 columns]

# %%
# V. showcase

alt.data_transformers.enable('default', max_rows=None)

nearest = alt.selection(type='single', nearest=True, on='mouseover',
                            fields=['Country', 'Value', 'Variable', 'Year'])

alt.Chart(wvsSummaryCC).mark_line().encode(
    alt.X('Year:O'),
    alt.Y('Value:Q', axis=alt.Axis(labelAngle=-45)),
    #alt.Color('Variable:N'),
    alt.Color('Country:N'),
    alt.Tooltip(['Country', 'Value', 'Variable', 'Year'])
).facet(
    #column='Country:N'
    facet='Variable:N',
    columns=2
).add_selection(
    nearest
).resolve_scale(x='independent', y='independent')

# TODO nicer tooltips:
# https://stackoverflow.com/questions/53287928/tooltips-in-altair-line-charts
# Out:
# alt.FacetChart(...)

# %%
cpi2001 = cpi_norm.loc[cpi_norm['Year'] == '2001']
cpi2001

countryCodes_noindex = countryCodes.reset_index().rename(columns={'name': 'Country'})

lookupData = pd.merge(cpi2001, countryCodes_noindex, on='Country')
lookupData
# Out:
#          Country  Year  Value                     Variable  country-code
# 0    Afghanistan  2001    NaN  Corruption Perception Index             4
# 1        Albania  2001    NaN  Corruption Perception Index             8
# 2        Algeria  2001    NaN  Corruption Perception Index            12
# 3         Angola  2001    NaN  Corruption Perception Index            24
# 4      Argentina  2001   0.65  Corruption Perception Index            32
# ..           ...   ...    ...                          ...           ...
# 162      Vanuatu  2001    NaN  Corruption Perception Index           548
# 163     Viet Nam  2001    NaN  Corruption Perception Index           704
# 164        Yemen  2001    NaN  Corruption Perception Index           887
# 165       Zambia  2001   0.74  Corruption Perception Index           894
# 166     Zimbabwe  2001   0.71  Corruption Perception Index           716
#
# [167 rows x 5 columns]

# %%
# TODO how do we feed CPI values into this?
# https://altair-viz.github.io/gallery/choropleth.html
# https://groups.google.com/g/vega-js/c/JD3TjOlRbUQ

import altair as alt
from vega_datasets import data

#lookupData = wvsSummary.loc[wvsSummary['Variable'] == 'Feeling of happiness'].loc[wvsSummary['Year'] == 2001]
#lookupData = cpi_norm.loc[cpi_norm['Year'] == 2001]
source = alt.topo_feature(data.world_110m.url, 'countries')

alt.Chart(source).mark_geoshape(
    fill='#666666',
    stroke='white'
) + alt.Chart(source, title='Corruption Perception Worldwide').mark_geoshape(
    #fill='#666666',
    stroke='white'
).project(
    'naturalEarth1'
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(data=lookupData, key='country-code', fields=['Value'])
).encode(
    color=alt.Color('Value:Q',  scale=alt.Scale(scheme='reds'))
).properties(
    width=800,
    height=400
)
# Out:
# alt.LayerChart(...)

# %%
#happiness2001 = wvsSummaryCC.loc[wvsSummaryCC['Year'] == 2006]
happiness = wvsSummaryCC.loc[wvsSummaryCC['Variable'] == 'Feeling of happiness']

#happiness2001['country-code'] = happiness2001['country-code'].astype(np.int64)
#happiness2001['country-code']
lookupData = pd.merge(happiness, countryCodes_noindex, on='Country')
lookupData
# Out:
#     Year                   Country              Variable     Value  \
# 0   1982              South Africa  Feeling of happiness  0.682617
# 1   1990              South Africa  Feeling of happiness  0.656250
# 2   1996              South Africa  Feeling of happiness  0.718750
# 3   2001              South Africa  Feeling of happiness  0.739258
# 4   2006              South Africa  Feeling of happiness  0.744141
# 5   2013              South Africa  Feeling of happiness  0.708984
# 6   1982  United States of America  Feeling of happiness  0.739258
# 7   1990  United States of America  Feeling of happiness  0.759766
# 8   1995  United States of America  Feeling of happiness  0.799316
# 9   1999  United States of America  Feeling of happiness  0.777344
# 10  2006  United States of America  Feeling of happiness  0.758789
# 11  2011  United States of America  Feeling of happiness  0.754395
# 12  2017  United States of America  Feeling of happiness  0.706055
# 13  1990                   Belarus  Feeling of happiness  0.487061
# 14  1996                   Belarus  Feeling of happiness  0.472412
# 15  2011                   Belarus  Feeling of happiness  0.587891
# 16  1990                     China  Feeling of happiness  0.648926
# 17  1995                     China  Feeling of happiness  0.684570
# 18  2001                     China  Feeling of happiness  0.623047
# 19  2007                     China  Feeling of happiness  0.645508
# 20  2013                     China  Feeling of happiness  0.668945
# 21  2018                     China  Feeling of happiness  0.716797
# 22  1990        Russian Federation  Feeling of happiness  0.514648
# 23  1995        Russian Federation  Feeling of happiness  0.498779
# 24  2006        Russian Federation  Feeling of happiness  0.588867
# 25  2011        Russian Federation  Feeling of happiness  0.633301
# 26  2017        Russian Federation  Feeling of happiness  0.660645
# 27  1991                    Brazil  Feeling of happiness  0.648926
# 28  1997                    Brazil  Feeling of happiness  0.676758
# 29  2006                    Brazil  Feeling of happiness  0.746582
# 30  2014                    Brazil  Feeling of happiness  0.753906
# 31  2018                    Brazil  Feeling of happiness  0.724121
# 32  1997                  Colombia  Feeling of happiness       NaN
# 33  1998                  Colombia  Feeling of happiness  0.768066
# 34  2005                  Colombia  Feeling of happiness  0.783203
# 35  2012                  Colombia  Feeling of happiness  0.825684
# 36  2018                  Colombia  Feeling of happiness  0.817871
# 37  1997                   Germany  Feeling of happiness  0.655762
# 38  2006                   Germany  Feeling of happiness  0.658203
# 39  2013                   Germany  Feeling of happiness  0.696777
# 40  2018                   Germany  Feeling of happiness  0.719727
# 41  2001                     Egypt  Feeling of happiness  0.687500
# 42  2008                     Egypt  Feeling of happiness  0.641113
# 43  2013                     Egypt  Feeling of happiness  0.313232
# 44  2018                     Egypt  Feeling of happiness  0.575684
# 45  2002                   Algeria  Feeling of happiness  0.655273
# 46  2014                   Algeria  Feeling of happiness  0.648438
#
#     country-code
# 0            710
# 1            710
# 2            710
# 3            710
# 4            710
# 5            710
# 6            840
# 7            840
# 8            840
# 9            840
# 10           840
# 11           840
# 12           840
# 13           112
# 14           112
# 15           112
# 16           156
# 17           156
# 18           156
# 19           156
# 20           156
# 21           156
# 22           643
# 23           643
# 24           643
# 25           643
# 26           643
# 27            76
# 28            76
# 29            76
# 30            76
# 31            76
# 32           170
# 33           170
# 34           170
# 35           170
# 36           170
# 37           276
# 38           276
# 39           276
# 40           276
# 41           818
# 42           818
# 43           818
# 44           818
# 45            12
# 46            12

# %%
source = alt.topo_feature(data.world_110m.url, 'countries')

alt.Chart(source).mark_geoshape(
    fill='#666666',
    stroke='white'
) + alt.Chart(source, title='Feeling of happiness').mark_geoshape(
    #fill='#666666',
    stroke='white'
).project(
    'naturalEarth1'
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(data=lookupData, key='country-code', fields=['Value'])
).encode(
    color=alt.Color('Value:Q',  scale=alt.Scale(scheme='blues'))
).properties(
    width=800,
    height=400
)
# Out:
# alt.LayerChart(...)

# %%
politics = wvsSummaryCC.loc[wvsSummaryCC['Variable'] == 'Political system: Having a democratic political system']
lookupData = pd.merge(politics, countryCodes_noindex, on='Country')
lookupData
# Out:
#     Year                   Country  \
# 0   1982              South Africa
# 1   1990              South Africa
# 2   1996              South Africa
# 3   2001              South Africa
# 4   2006              South Africa
# 5   2013              South Africa
# 6   1982  United States of America
# 7   1990  United States of America
# 8   1995  United States of America
# 9   1999  United States of America
# 10  2006  United States of America
# 11  2011  United States of America
# 12  2017  United States of America
# 13  1990                   Belarus
# 14  1996                   Belarus
# 15  2011                   Belarus
# 16  1990                     China
# 17  1995                     China
# 18  2001                     China
# 19  2007                     China
# 20  2013                     China
# 21  2018                     China
# 22  1990        Russian Federation
# 23  1995        Russian Federation
# 24  2006        Russian Federation
# 25  2011        Russian Federation
# 26  2017        Russian Federation
# 27  1991                    Brazil
# 28  1997                    Brazil
# 29  2006                    Brazil
# 30  2014                    Brazil
# 31  2018                    Brazil
# 32  1997                  Colombia
# 33  1998                  Colombia
# 34  2005                  Colombia
# 35  2012                  Colombia
# 36  2018                  Colombia
# 37  1997                   Germany
# 38  2006                   Germany
# 39  2013                   Germany
# 40  2018                   Germany
# 41  2001                     Egypt
# 42  2008                     Egypt
# 43  2013                     Egypt
# 44  2018                     Egypt
# 45  2002                   Algeria
# 46  2014                   Algeria
#
#                                              Variable     Value  country-code
# 0   Political system: Having a democratic politica...       NaN           710
# 1   Political system: Having a democratic politica...       NaN           710
# 2   Political system: Having a democratic politica...  0.787598           710
# 3   Political system: Having a democratic politica...  0.777344           710
# 4   Political system: Having a democratic politica...  0.797363           710
# 5   Political system: Having a democratic politica...  0.668457           710
# 6   Political system: Having a democratic politica...       NaN           840
# 7   Political system: Having a democratic politica...       NaN           840
# 8   Political system: Having a democratic politica...  0.809082           840
# 9   Political system: Having a democratic politica...  0.786621           840
# 10  Political system: Having a democratic politica...  0.768555           840
# 11  Political system: Having a democratic politica...  0.733887           840
# 12  Political system: Having a democratic politica...  0.765137           840
# 13  Political system: Having a democratic politica...       NaN           112
# 14  Political system: Having a democratic politica...  0.665039           112
# 15  Political system: Having a democratic politica...  0.717773           112
# 16  Political system: Having a democratic politica...       NaN           156
# 17  Political system: Having a democratic politica...       NaN           156
# 18  Political system: Having a democratic politica...  0.724121           156
# 19  Political system: Having a democratic politica...  0.757324           156
# 20  Political system: Having a democratic politica...  0.749023           156
# 21  Political system: Having a democratic politica...  0.750977           156
# 22  Political system: Having a democratic politica...       NaN           643
# 23  Political system: Having a democratic politica...  0.508789           643
# 24  Political system: Having a democratic politica...  0.664551           643
# 25  Political system: Having a democratic politica...  0.665527           643
# 26  Political system: Having a democratic politica...  0.657715           643
# 27  Political system: Having a democratic politica...       NaN            76
# 28  Political system: Having a democratic politica...  0.688965            76
# 29  Political system: Having a democratic politica...  0.727051            76
# 30  Political system: Having a democratic politica...  0.690430            76
# 31  Political system: Having a democratic politica...  0.736328            76
# 32  Political system: Having a democratic politica...  0.717285           170
# 33  Political system: Having a democratic politica...  0.736328           170
# 34  Political system: Having a democratic politica...  0.706543           170
# 35  Political system: Having a democratic politica...  0.708984           170
# 36  Political system: Having a democratic politica...  0.729004           170
# 37  Political system: Having a democratic politica...  0.815430           276
# 38  Political system: Having a democratic politica...  0.837891           276
# 39  Political system: Having a democratic politica...  0.871582           276
# 40  Political system: Having a democratic politica...  0.921875           276
# 41  Political system: Having a democratic politica...  0.887695           818
# 42  Political system: Having a democratic politica...  0.922363           818
# 43  Political system: Having a democratic politica...  0.889648           818
# 44  Political system: Having a democratic politica...  0.853027           818
# 45  Political system: Having a democratic politica...  0.832520            12
# 46  Political system: Having a democratic politica...  0.815430            12

# %%
source = alt.topo_feature(data.world_110m.url, 'countries')

alt.Chart(source).mark_geoshape(
    fill='#666666',
    stroke='white'
) + alt.Chart(source, title='Political system: Having a democratic political system').mark_geoshape(
    #fill='#666666',
    stroke='white'
).project(
    'naturalEarth1'
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(data=lookupData, key='country-code', fields=['Value'])
).encode(
    color=alt.Color('Value:Q',  scale=alt.Scale(scheme='greens'))
).properties(
    width=800,
    height=400
)
# Out:
# alt.LayerChart(...)
